# %%
def linear(x):
    return 3**x

mylist = [i for i in range(24)]

listo = list(map(linear, mylist))

print(listo)
# Out:
# [1, 3, 9, 27, 81, 243, 729, 2187, 6561, 19683, 59049, 177147, 531441, 1594323, 4782969, 14348907, 43046721, 129140163, 387420489, 1162261467, 3486784401, 10460353203, 31381059609, 94143178827]

# %%
import pandas as pd

my_dict = {"Name": ["Miguel", "Mike", "Angel"] , "Age": [22,33,23]}

df = pd.DataFrame(my_dict)

# %%
print(type(df["Name"]))
print(type(df[["Name"]]))
# Out:
# <class 'pandas.Series'>
# <class 'pandas.DataFrame'>
